# %%
#Upload file
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-fa235ee9-cd0e-468c-9592-557c8e2b2873" name="files[]" multiple disabled />
#      <output id="result-fa235ee9-cd0e-468c-9592-557c8e2b2873">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving face_detection.jpg to face_detection.jpg
# User uploaded file "face_detection.jpg" with length 52491 bytes

# %%
# CMD install mtcnn
# !pip3 install mtcnn
# Out:
# Collecting mtcnn
#   Downloading https://files.pythonhosted.org/packages/0b/f5/d62ac2bdf1c683b7650268305db3126323a7b6a2f6390273038285fa9e3f/mtcnn-0.0.8.tar.gz (2.3MB)
#     100% |████████████████████████████████| 2.3MB 9.7MB/s
# Building wheels for collected packages: mtcnn
#   Building wheel for mtcnn (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/be/dd/12/bccde6b95f576af24256f6f1a2e4087eb8488405a6c107e13c
# Successfully built mtcnn
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.0.8

# %%
# Face detection and drawing
import cv2
from mtcnn.mtcnn import MTCNN

detector = MTCNN()

image = cv2.imread("face_detection.jpg")
result = detector.detect_faces(image)

# Result is an array with all the bounding boxes detected. We know that for 'ivan.jpg' there is only one.
bounding_box = result[0]['box']
keypoints = result[0]['keypoints']

cv2.rectangle(image,
              (bounding_box[0], bounding_box[1]),
              (bounding_box[0]+bounding_box[2], bounding_box[1] + bounding_box[3]),
              (0,155,255),
              2)

cv2.circle(image,(keypoints['left_eye']), 2, (0,155,255), 2)
cv2.circle(image,(keypoints['right_eye']), 2, (0,155,255), 2)
cv2.circle(image,(keypoints['nose']), 2, (0,155,255), 2)
cv2.circle(image,(keypoints['mouth_left']), 2, (0,155,255), 2)
cv2.circle(image,(keypoints['mouth_right']), 2, (0,155,255), 2)

cv2.imwrite("lnd_drawn.jpg", image)

print(result)
# Out:
# [{'box': [106, 66, 151, 201], 'confidence': 0.9949709177017212, 'keypoints': {'left_eye': (146, 139), 'right_eye': (211, 159), 'nose': (155, 187), 'mouth_left': (131, 215), 'mouth_right': (183, 232)}}]

# %%
# show drawed image
import matplotlib.pyplot as plt
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
